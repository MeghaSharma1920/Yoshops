# %%
#IMPORT LIBRARIES
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# IMPORT DATASET
dataset = pd.read_csv("E:/internships/yoshops/orders_2020_2021_DataSet_Updated.csv")
data_review = pd.read_csv("E:/internships/yoshops/review_dataset.csv")

# %% [markdown]
# # Cleaning data_review

# %%
data_review = data_review.dropna()
data_review = data_review.drop_duplicates()
data_review.columns = data_review.columns.str.replace(" ","")
data_review.head()
# Out:
#                                         product_name  \
# 0  Sony PlayStation PS2 Gaming Console 150 GB Har...
# 1           Vmax HX 750 Quadcopter Drone (No Camera)
# 2  Yoshops VR BOX Virtual Reality Glasses Headset...
# 3   Sony PlayStation PS3 Console Slim 320 GB (Black)
# 4                                 Barbie Doll (pink)
#
#                                          product_url      category   status  \
# 0  https://yoshops.com/products/sony-playstation-...  Toys & Games  Reviewd
# 1  https://yoshops.com/products/hx-750-remote-con...  Toys & Games  Reviewd
# 2  https://yoshops.com/products/yoshops-vr-box-vi...  Toys & Games  Reviewd
# 3  https://yoshops.com/products/sony-playstation-...  Toys & Games  Reviewd
# 4           https://yoshops.com/products/barbie-doll  Toys & Games  Reviewd
#
#              stars
# 0  5.0 star rating
# 1  5.0 star rating
# 2  5.0 star rating
# 3  4.9 star rating
# 4  4.9 star rating

# %%
#column 'status' coorecting reviewed
data_review['status'] = data_review['status'].replace(['Reviewd'],'Reviewed')

# %%
# Make Reviews clearly in terms of numbers
data_review['stars'] = data_review['stars'].replace(['5.0 star rating'],5)
data_review['stars'] = data_review['stars'].replace(['4.9 star rating'],4.9)
data_review['stars'] = data_review['stars'].replace(['4.8 star rating'],4.8)
data_review['stars'] = data_review['stars'].replace(['4.7 star rating'],4.7)
data_review['stars'] = data_review['stars'].replace(['4.6 star rating'],4.6)
data_review['stars'] = data_review['stars'].replace(['4.5 star rating'],4.5)
data_review['stars'] = data_review['stars'].replace(['4.3 star rating'],4.3)
data_review['stars'] = data_review['stars'].replace(['4.2 star rating'],4.2)
data_review['stars'] = data_review['stars'].replace(['4.0 star rating'],4)
data_review['stars'] = data_review['stars'].replace(['3.3 star rating'],3.3)
data_review['stars'] = data_review['stars'].replace(['3.0 star rating'],3)
data_review['stars'] = data_review['stars'].replace(['2.3 star rating'],2.3)

# %%
data_review = data_review.assign(Category_Distinct = data_review.category)

# %%
#from column category bringing all type of laptops into 1 category .i.e 'laptops'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Gaming Laptops'],'Laptops')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Personal Laptops'],'Laptops')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Tablets'], 'Laptops')

# %%
#from column category bringing all type of mobiles into 1 category .i.e 'mobiles'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Smartphones'], 'Mobiles')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Feature Keypad Mobiles'], 'Mobiles')

# %%
#from column category bringing all type of accessories into 1 category .i.e 'Accessories'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Gaming Accessories'], 'Accessories')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Mobiles Accessories'], 'Accessories')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Laptop Accessories'], 'Accessories')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Computers Accessories'], 'Accessories')

# %%
#from column category bringing all type of ' spare parts'into 1 category .i.e 'spare parts'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Auto spare parts'], 'SpareParts')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Mobile Spare Parts'],'SpareParts')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Laptop spare parts'], 'SpareParts')

# %%
#from column category bringing all type of 'more' into 1 category .i.e ''Others'' and 'Face Makeup'  to 'Personal Care'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['More'], 'Others')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Face Makeup'], 'Personal Care')

# %%
#from column category bringing all type of ''Electronics'' into 1 category .i.e ''Electronics''
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Led TV'], 'Electronics')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Irons'], 'Electronics')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Mixer Grinder Juicer'], 'Electronics')

# %%
#from column category bringing all type of 'Fashion' into 1 category .i.e 'men fashion'
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Men'], 'men fashion')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(["Men's Footwear"], 'men fashion')

# %%
#from column category bringing all type of food into 1 category .i.e food
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Non Veg' ], 'Foods')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Biryani'],'Foods')

# %%
#from column category bringing all type of services into 1 category .i.e 'services
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Online Live Tuition'],'Services')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Training Internship Work From Home'],'Services')

# %%
#from column category bringing all type of marketings to 1 marketings
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Sponsorship Marketing'],'Marketing')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Blog Sponsorship'],'Marketing')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Instagram Sponsorship'],'Marketing')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['YouTube Sponsorship'],'Marketing')

# %%
#from column category bringing all type of to toys
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Toys & Games'],'Toys')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['PlayStation'],'Toys')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Drones'],'Toys')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['RC Toys'],'Toys')

# %%
#from column category bringing all type of cities to 1 city
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace(['Bengaluru'],'city')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Chennai'],'city')
data_review['Category_Distinct'] = data_review['Category_Distinct'].replace([ 'Mumbai'],'city')
data_review.head()
# Out:
#                                         product_name  \
# 0  Sony PlayStation PS2 Gaming Console 150 GB Har...
# 1           Vmax HX 750 Quadcopter Drone (No Camera)
# 2  Yoshops VR BOX Virtual Reality Glasses Headset...
# 3   Sony PlayStation PS3 Console Slim 320 GB (Black)
# 4                                 Barbie Doll (pink)
#
#                                          product_url      category    status  \
# 0  https://yoshops.com/products/sony-playstation-...  Toys & Games  Reviewed
# 1  https://yoshops.com/products/hx-750-remote-con...  Toys & Games  Reviewed
# 2  https://yoshops.com/products/yoshops-vr-box-vi...  Toys & Games  Reviewed
# 3  https://yoshops.com/products/sony-playstation-...  Toys & Games  Reviewed
# 4           https://yoshops.com/products/barbie-doll  Toys & Games  Reviewed
#
#    stars Category_Distinct
# 0    5.0              Toys
# 1    5.0              Toys
# 2    5.0              Toys
# 3    4.9              Toys
# 4    4.9              Toys

# %% [markdown]
# # Cleaning DATASET

# %%
dataset.shape
# Out:
# (3039, 38)

# %%
dataset.isnull().sum()
# Out:
# Order #                               0
# Fulfillment Date and Time Stamp    2801
# Currency                              0
# Subtotal                              0
# Shipping Method                       0
# Shipping Cost                         0
# Tax Method                         3038
# Taxes                                 0
# Total                                 0
# Coupon Code                        2797
# Coupon Code Name                   2797
#                                       0
# Billing Name                       2664
# Billing Country                    2664
# Billing Street Address             2664
# Billing Street Address 2           2811
# Billing City                       2664
# Billing State                      2670
# Billing Zip                        2664
# Shipping Name                         0
# Shipping Country                      0
# Shipping Street Address              19
# Shipping Street Address 2           982
# ...

# %%
# Since certain columns have null values for all obervation........one can delete the entire column
dataset = dataset.drop(['Download Status', 'Special Instructions', 'Gift Cards', 'Tax Method',' '], axis=1)

# %% [markdown]
# # 1. Analysis of Reviews given by Customers

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x = data_review['stars'],palette=['#432371',"#FAAE7B"])
ax.set(title='Analysis of Reviews given by Customers')
for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.25,p.get_height()+3.11))
plt.show()

# %% [markdown]
# # 2. Analysis of different payment methods used by the Customers

# %%
#splitting payment column into 3 different columns
df1 = dataset['Payment Method']
df1 = df1.dropna()
df1 = df1.str.split('₹',expand = True)
df1.head(5)
# Out:
#              0         1     2
# 26   CCAvenue     999.00  None
# 137  CCAvenue     219.00  None
# 138  CCAvenue   1,499.00  None
# 146  CCAvenue     349.00  None
# 147  CCAvenue     799.00  None

# %%
df1 = df1[df1[1].str.contains('Offline Payment') == False]

# %%
plt.figure(figsize=(4,4))
ax = sns.countplot(x = df1[0],palette=['#ffd92f', '#e5c494', '#b3b3b3'])
ax.set(title = " Analysis of different payment methods used by the Customers")
for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.25,p.get_height()+3.11))
plt.show()

# %% [markdown]
# # 3. Analysis of Top Consumer States of India

# %%
df2 = dataset['Shipping State']
df2 = df2.dropna()
df2 = pd.DataFrame(df2)

# %%
df2.columns = ['Shipping State']
df2.head()
# Out:
#   Shipping State
# 0          IN-MH
# 1          IN-MH
# 2          IN-MH
# 3          IN-MH
# 4          IN-DL

# %%
df2 = df2[df2['Shipping State'].str.contains('IN')]

# %%
df2['Shipping State'].unique()
# Out:
# array(['IN-MH', 'IN-DL', 'IN-OR', 'IN-UT', 'IN-HR', 'IN-MP', 'IN-GJ',
#        'IN-TG', 'IN-JH', 'IN-UP', 'IN-KA', 'IN-CT', 'IN-WB', 'IN-TN',
#        'IN-MZ', 'IN-AS', 'IN-JK', 'IN-RJ', 'IN-AN', 'IN-KL', 'IN-AP',
#        'IN-BR', 'IN-HP', 'IN-MN', 'IN-DN', 'IN-PY', 'IN-PB', 'IN-SK',
#        'IN-NL', 'IN-DD', 'IN-TR', 'IN-CH', 'IN-ML', 'IN-GA', 'IN',
#        'IN-AR'], dtype=object)

# %%
# As we know,in total we have 37 states + union territories.
df2 = df2[(df2['Shipping State'] != 'IN-UT') & (df2['Shipping State'] != 'IN-TG') & (df2['Shipping State'] != 'IN-CT') & (df2['Shipping State'] != 'IN-DN') & (df2['Shipping State'] != 'IN') & (df2['Shipping State'] != 'IN-AR')]

# %%
plt.figure(figsize=(18,4))
ax = sns.countplot(x = df2['Shipping State'],palette=['#35193e', '#701f57', '#ad1759', '#e13342', '#f37651', '#f6b48f'])
ax.set(title = "Analysis of Top Consumer States of India")
for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.25,p.get_height()+3.11))
plt.show()

# %% [markdown]
# # 4. Analysis of Top Consumer Cities of India

# %%
df3 = dataset[['Shipping City','LineItem Sale Price']]
df3 = df3.dropna()
df3 = pd.DataFrame(df3)

# %%
df3.columns = ['Shipping City','LineItem Sale Price']

# %%
df3 = df3[df3['Shipping City'].str.contains('1') == False]
df3 = df3[df3['Shipping City'].str.contains('2') == False]
df3 = df3[df3['Shipping City'].str.contains('3') == False]
df3 = df3[df3['Shipping City'].str.contains('4') == False]
df3 = df3[df3['Shipping City'].str.contains('5') == False]
df3 = df3[df3['Shipping City'].str.contains('6') == False]
df3 = df3[df3['Shipping City'].str.contains('7') == False]
df3 = df3[df3['Shipping City'].str.contains('8') == False]
df3 = df3[df3['Shipping City'].str.contains('9') == False]
df3 = df3[df3['Shipping City'].str.contains('0') == False]
df3 = df3[df3['Shipping City'].str.contains(',') == False]

# %%
#correcting city names
df3['Shipping City'] = df3['Shipping City'].replace(['Bengaluru'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['bangalore south'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['New Delhi West'],'Delhi')
df3['Shipping City'] = df3['Shipping City'].replace(['Ncl kompaly'],'NCL')
df3['Shipping City'] = df3['Shipping City'].replace(['Ncl'],'NCL')
df3['Shipping City'] = df3['Shipping City'].replace(['Hyd'],'Hyderabad')
df3['Shipping City'] = df3['Shipping City'].replace(['Pune City East'],'Pune')
df3['Shipping City'] = df3['Shipping City'].replace(['Ahemdabad'],'Ahmedabad')
df3['Shipping City'] = df3['Shipping City'].replace(['BENGALURU'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['BENGALURU'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['Dist-Pune'],'Pune')
df3['Shipping City'] = df3['Shipping City'].replace(['Rayagada odisha'],'Rayagada')
df3['Shipping City'] = df3['Shipping City'].replace(['Chenai'],'Chennai')
df3['Shipping City'] = df3['Shipping City'].replace(['BERHAMPUR'],'Brahmapur')
df3['Shipping City'] = df3['Shipping City'].replace(['berhampur'],'Brahmapur')
df3['Shipping City'] = df3['Shipping City'].replace(['berhampur'],'Brahmapur')
df3['Shipping City'] = df3['Shipping City'].replace(['Bengaluru'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['NAVI MUMBAI'],'Mumbai')
df3['Shipping City'] = df3['Shipping City'].replace(['Greater Noida West'],'Noida')
df3['Shipping City'] = df3['Shipping City'].replace(['CHENNAI'],'Chennai')
df3['Shipping City'] = df3['Shipping City'].replace(['Ambajogai'],'Ambejogai')
df3['Shipping City'] = df3['Shipping City'].replace(['Dombivli east'],'Dombivli')
df3['Shipping City'] = df3['Shipping City'].replace(['West Delhi'],'Delhi')
df3['Shipping City'] = df3['Shipping City'].replace(['Banglore'],'BANGALORE')
df3['Shipping City'] = df3['Shipping City'].replace(['South West Delhi'],'Delhi')
df3['Shipping City'] = df3['Shipping City'].replace(['New Delhi'],'Delhi')
df3['Shipping City'] = df3['Shipping City'].replace(['NEW DELHI'],'Delhi')
df3['Shipping City'] = df3['Shipping City'].replace(['chennai'],'Chennai')

# %%
df3 = df3[(df3['Shipping City'] != 'Zurich') & (df3['Shipping City'] != 'Sligarh up') & (df3['Shipping City'] != 'nan') & (df3['Shipping City'] != 'aaaaaaaaaaaaaaaaaaaaa') & (df3['Shipping City'] != 'peshawar') & (df3['Shipping City'] != 'Houston') & (df3['Shipping City'] != 'hotcourses')& (df3['Shipping City'] != ';lkjhgf') & (df3['Shipping City'] != 'pauri garhwal') & (df3['Shipping City'] != 'test') & (df3['Shipping City'] != 'sdas') & (df3['Shipping City'] != 'dwwwwwwww') & (df3['Shipping City'] != 'Rustenburg') & (df3['Shipping City'] != 'Gccch') & (df3['Shipping City'] != 'Utrecht') & (df3['Shipping City'] != 'Anantnag') & (df3['Shipping City'] != 'India') & (df3['Shipping City'] != 'Rajasthan') & (df3['Shipping City'] != 'bbsr') & (df3['Shipping City'] != 'Others') & (df3['Shipping City'] != 'DEL') & (df3['Shipping City'] != 'Erode') & (df3['Shipping City'] != 'Karungal') & (df3['Shipping City'] != 'panel') & (df3['Shipping City'] != 'Town') & (df3['Shipping City'] != 'City') & (df3['Shipping City'] != 'Bogotá') & (df3['Shipping City'] != 'tvm')& (df3['Shipping City'] != 'Raina')& (df3['Shipping City'] != 'gtrtgt') & (df3['Shipping City'] != 'Inkollui') & (df3['Shipping City'] != 'Montpellier')& (df3['Shipping City'] != 'Singaperumal koil') & (df3['Shipping City'] != 'Navi Mumbai Thane rabadi')& (df3['Shipping City'] != 'Ara')& (df3['Shipping City'] != 'aspur')& (df3['Shipping City'] != 'Montpellier')& (df3['Shipping City'] != 'kodumudi')& (df3['Shipping City'] != 'Orai')& (df3['Shipping City'] != 'Kadapa did. Rayachoty mandal')& (df3['Shipping City'] != 'Jajpur roas')& (df3['Shipping City'] != 'Old city gowlipure')& (df3['Shipping City'] != 'TELANGANA')& (df3['Shipping City'] != 'Panvel')& (df3['Shipping City'] != 'PEDDAPALLI')& (df3['Shipping City'] != 'dhar in mp')& (df3['Shipping City'] != 'Ranga reddy') & (df3['Shipping City'] != 'Amaravati')& (df3['Shipping City'] != 'Village piplya indore')& (df3['Shipping City'] != 'Maripeda Banglow')& (df3['Shipping City'] != 'X')& (df3['Shipping City'] != 'Chengalpattu')& (df3['Shipping City'] !='Jogiya') & (df3['Shipping City'] !='district Shajapur')& (df3['Shipping City'] !='chanditala')& (df3['Shipping City'] !='KumarPara') & (df3['Shipping City'] !='Bhuntar')& (df3['Shipping City'] !='URULI KANCHAN')& (df3['Shipping City'] !='Duttapukur')]

# %%
# To extract data of top consumer state
df4 = df3.groupby(['Shipping City'])['LineItem Sale Price'].sum().nlargest(25)
df4 = df4.sort_values(ascending=False)

# %%
plt.title( "Analysis of Top Consumer Cities of India" , size = 24)
c = ['#a03704','#d55607','#f4811d','#feb23f','#feda7e','#fff4b6']

ax = df4.plot.bar(figsize=(24, 8), color = c)

plt.xlabel('Shipping City', fontsize=18)
plt.ylabel('Count', fontsize=16)

for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.05,p.get_height()+4))
plt.show()

# %% [markdown]
# # 5. Analysis of Top Selling Product Categories

# %%
plt.figure(figsize=(14,18))
data_review['category'].value_counts()[:].plot(kind='barh',color ='#fc8d62')
plt.xlabel('Count', fontsize=18)
plt.ylabel('Product Categories', fontsize=16)
# Out:
# Text(0, 0.5, 'Product Categories')

# %%
plt.figure(figsize=(8,4))
data_review['Category_Distinct'].value_counts()[:].plot(kind='barh',color = '#e78ac3')
plt.xlabel('Count', fontsize=18)
plt.ylabel('Distinct Product Categories', fontsize=16)
# Out:
# Text(0, 0.5, 'Distinct Product Categories')

# %% [markdown]
# # 6. Analysis of Reviews for All Product Categories

# %%
# To do analysis of reviews of different product categories
plt.figure(figsize=(18,4))
df5 = data_review.groupby(['category'])['stars'].mean()
df5.plot.bar(title="Analysis of Reviews for All Product Categories" ,color = '#a6d854')
# Out:
# <AxesSubplot:title={'center':'Analysis of Reviews for All Product Categories'}, xlabel='category'>

# %%
df6 = data_review['stars']
df6.dropna()
df6 = pd.DataFrame(df6)
df6.columns = ['stars']

# %%
df6['stars'] = df6['stars'].astype(str)

# %%
#correcting stars names
df6['stars'] = df6['stars'].replace(['5.'],'4-5')
df6['stars'] = df6['stars'].replace(['5.0'],'4-5')
df6['stars'] = df6['stars'].replace(['4.9'],'4-5')
df6['stars'] = df6['stars'].replace(['4.6'],'4-5')
df6['stars'] = df6['stars'].replace(['4.8'],'4-5')
df6['stars'] = df6['stars'].replace(['4.3'],'4-5')
df6['stars'] = df6['stars'].replace(['4.7'],'4-5')
df6['stars'] = df6['stars'].replace(['4.2'],'4-5')
df6['stars'] = df6['stars'].replace(['4.5'],'4-5')

df6['stars'] = df6['stars'].replace(['3.3'],'3-4')
df6['stars'] = df6['stars'].replace(['4.'],'3-4')

df6['stars'] = df6['stars'].replace(['3.'],'2-3')
df6['stars'] = df6['stars'].replace(['2.3'],'2-3')

# %%
# To do analysis of reviews of different product categories
plt.figure(figsize=(8,4))
ax = sns.countplot(x = df6['stars'],palette=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3'])
ax.set(title='Count of  Products belonging to different categories of stars')
for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.25,p.get_height()+0.01))
plt.show()

# %% [markdown]
# # 7. Analysis of Number of Orders Per Month Per Year

# %%
# Extract columns Order and Fulfillment Date and Time Stamp to analyse -- Number of Orders Per Month Per Year
df7 = dataset[['Order #', 'Fulfillment Date and Time Stamp']].dropna()
# Split the column "Fulfillment Date and Time Stamp" properly into year month date and hour
df7['Dates'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.date
df7['Time'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.time
df7['year'] = pd.DatetimeIndex(df7['Dates']).year
df7['month'] = pd.DatetimeIndex(df7['Dates']).month
df7['day'] = pd.DatetimeIndex(df7['Dates']).day
df7['time_hour'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.hour

# %%
# Rename months in an year
df7['month'] = df7['month'].replace([1],'January')
df7['month'] = df7['month'].replace([2],'February')
df7['month'] = df7['month'].replace([3],'March')
df7['month'] = df7['month'].replace([4],'April')
df7['month'] = df7['month'].replace([5],'May')
df7['month'] = df7['month'].replace([6],'June')
df7['month'] = df7['month'].replace([7],'July')
df7['month'] = df7['month'].replace([8],'August')
df7['month'] = df7['month'].replace([9],'September')
df7['month'] = df7['month'].replace([10],'October')
df7['month'] = df7['month'].replace([11],'November')
df7['month'] = df7['month'].replace([12],'December')

# %%
k = ['#fca55d', '#fee999', '#edf8a3','#fff4b6', '#feda7e', '#feb23f', '#f4811d', '#d55607', '#a03704']
fig, axes = plt.subplots(3, 2, figsize=(25,20), sharey=True)
fig.suptitle('Analysis of Number of Orders Per Month Per Year', size=24)

sns.countplot(x='month', data=df7[(df7.year < 2017)], ax=axes[0, 0],palette = ['#fca55d', '#fee999', '#edf8a3'])
axes[0, 0].set_title('months of year 2016')

sns.countplot(x='month', data=df7[(df7.year  < 2018) & (df7.year > 2016)], ax=axes[0, 1],palette = ['#f4811d', '#d55607', '#a03704'])
axes[0, 1].set_title('months of year 2017')

sns.countplot(x='month', data=df7[(df7.year  < 2019) & (df7.year > 2017)], ax=axes[1, 0],palette = ['#fff4b6', '#feda7e', '#feb23f'])
axes[1, 0].set_title('months of year 2018')

sns.countplot(x='month', data=df7[(df7.year  < 2020) & (df7.year > 2018)], ax=axes[1, 1],palette = ['#feda7e', '#feb23f', '#f4811d'])
axes[1, 1].set_title('months of year 2019')

sns.countplot(x='month', data=df7[(df7.year  < 2021) & (df7.year > 2019)], ax=axes[2, 0],palette = ['#feb23f', '#f4811d', '#d55607'])
axes[2, 0].set_title('months of year 2020')

sns.countplot(x='month', data=df7[(df7.year  < 2022) & (df7.year > 2020)], ax=axes[2, 1],palette =  ['#edf8a3','#fff4b6', '#feda7e'])
axes[2, 1].set_title('months of year 2021')

plt.show()

# %%
print(sns.color_palette("YlOrBr",as_cmap=False).as_hex())
# Out:
# ['#fff4b6', '#feda7e', '#feb23f', '#f4811d', '#d55607', '#a03704']

# %%
print(sns.color_palette("Set2", as_cmap=False).as_hex())
# Out:
# ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3']

# %%
print(sns.color_palette("Spectral",as_cmap=False).as_hex())
# Out:
# ['#e2514a', '#fca55d', '#fee999', '#edf8a3', '#a2d9a4', '#47a0b3']

# %% [markdown]
# # 8. Analysis of Number of Orders Across Parts of a Day

# %%
# Extract columns Order and Fulfillment Date and Time Stamp to analyse -- Number of Orders Per Month Per Year
df7 = dataset[['Order #', 'Fulfillment Date and Time Stamp']].dropna()
# Split the column "Fulfillment Date and Time Stamp" properly into year month date and hour
df7['Dates'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.date
df7['Time'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.time
df7['year'] = pd.DatetimeIndex(df7['Dates']).year
df7['month'] = pd.DatetimeIndex(df7['Dates']).month
df7['day'] = pd.DatetimeIndex(df7['Dates']).day
df7['time_hour'] = pd.to_datetime(df7['Fulfillment Date and Time Stamp']).dt.hour

# %%
df7['time_hour']
# Out:
# 15      18
# 18      18
# 21      18
# 254     15
# 292     22
#         ..
# 2995    21
# 2996    15
# 2998    21
# 2999    21
# 3038    19
# Name: time_hour, Length: 238, dtype: int64

# %%
# To do analysis of reviews of different product categories
plt.figure(figsize=(8,4))
ax = sns.countplot(x = df7['time_hour'],palette=['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3'])
ax.set(title='Count of  Products belonging hour of the day')
for p in ax.patches:
     ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.25,p.get_height()+0.01))
plt.show()
